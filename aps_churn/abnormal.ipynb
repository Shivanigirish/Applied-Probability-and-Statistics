# %%
# %pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (2.4.6)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.17.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.9.0)
# Collecting sklearn-compat<0.2,>=0.1.6 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\bda\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn<2,>=1.4.2->imbalanced-learn) (2.24.0)
# Downloading imbalanced_learn-0.14.2-py3-none-any.whl (236 kB)
# Downloading sklearn_compat-0.1.6-py3-none-any.whl (22 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
#
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.14.2 sklearn-compat-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    roc_auc_score,
    precision_recall_curve
)

from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv("dataset/Telco_abnormal.csv")

print(df.shape)
print(df["Churn"].value_counts())
# Out:
# (7043, 21)
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
no_churn = df[df["Churn"] == "No"]
churn = df[df["Churn"] == "Yes"]

churn_abnormal = churn.sample(
    frac=0.10,
    random_state=42
)

df = pd.concat([no_churn, churn_abnormal])

df = df.sample(
    frac=1,
    random_state=42
).reset_index(drop=True)

print(df["Churn"].value_counts())
# Out:
# Churn
# No     5174
# Yes     187
# Name: count, dtype: int64

# %%
df["Churn"].value_counts().plot(kind="bar")

plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.title("Abnormal Dataset Before SMOTE")
plt.xticks([0, 1], ["No Churn", "Churn"], rotation=0)

plt.show()

# %%
df["TotalCharges"] = pd.to_numeric(
    df["TotalCharges"],
    errors="coerce"
)

# %%
df = df.dropna()

# %%
df = df.drop("customerID", axis=1)

# %%
df["Churn"] = df["Churn"].map({
    "Yes": 1,
    "No": 0
})

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print("Before SMOTE:")
print(y_train.value_counts())
# Out:
# Before SMOTE:
# Churn
# 0    4130
# 1     150
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=42)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_scaled,
    y_train
)

# %%
print("After SMOTE:")
print(y_train_smote.value_counts())
# Out:
# After SMOTE:
# Churn
# 1    4130
# 0    4130
# Name: count, dtype: int64

# %%
model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

model.fit(X_train_smote, y_train_smote)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred = model.predict(X_test_scaled)

y_prob = model.predict_proba(X_test_scaled)[:, 1]

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7514018691588785

# %%
precision = precision_score(y_test, y_pred)

print("Precision:", precision)
# Out:
# Precision: 0.10921501706484642

# %%
recall = recall_score(y_test, y_pred)

print("Recall:", recall)
# Out:
# Recall: 0.8648648648648649

# %%
f1 = f1_score(y_test, y_pred)

print("F1 Score:", f1)
# Out:
# F1 Score: 0.19393939393939394

# %%
cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[772 261]
#  [  5  32]]

# %%
plt.figure(figsize=(6,5))

plt.imshow(cm)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Abnormal Dataset with SMOTE")

plt.xticks([0, 1], ["No Churn", "Churn"])
plt.yticks([0, 1], ["No Churn", "Churn"])

for i in range(2):
    for j in range(2):
        plt.text(
            j,
            i,
            cm[i, j],
            ha="center",
            va="center"
        )

plt.colorbar()
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob
)

# %%
auc = roc_auc_score(
    y_test,
    y_prob
)

print("AUC:", auc)
# Out:
# AUC: 0.867154182255828

# %%
plt.figure(figsize=(6,5))

plt.plot(
    fpr,
    tpr,
    label="AUC = {:.2f}".format(auc)
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Abnormal Dataset with SMOTE")

plt.legend()
plt.show()

# %%
precision_curve, recall_curve, thresholds = precision_recall_curve(
    y_test,
    y_prob
)

plt.figure(figsize=(6,5))

plt.plot(
    recall_curve,
    precision_curve
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve - Abnormal Dataset with SMOTE"

)

plt.show()
